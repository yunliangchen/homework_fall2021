# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorboard.backend.event_processing import event_accumulator

# %%
# %pwd
# Out:
# '/home/lawrence/homework_fall2021/hw2'

# %% [markdown]
# # Experiment 1

# %%
# Using a learning rate of 5e-3
ea_q1_lb_no_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_no_rtg_dsa_CartPole-v0_25-09-2021_15-30-59/events.out.tfevents.1632609059.triton2')
ea_q1_lb_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_rtg_dsa_CartPole-v0_25-09-2021_15-31-19/events.out.tfevents.1632609079.triton2')
ea_q1_lb_rtg_na = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_rtg_na_CartPole-v0_25-09-2021_15-31-57/events.out.tfevents.1632609117.triton2')
ea_q1_sb_no_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_no_rtg_dsa_CartPole-v0_25-09-2021_15-03-13/events.out.tfevents.1632607393.triton2')
ea_q1_sb_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_rtg_dsa_CartPole-v0_25-09-2021_15-29-03/events.out.tfevents.1632608943.triton2')
ea_q1_sb_rtg_na = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_rtg_na_CartPole-v0_25-09-2021_15-30-18/events.out.tfevents.1632609018.triton2')
ea_list = [ea_q1_sb_no_rtg_dsa, ea_q1_sb_rtg_dsa, ea_q1_sb_rtg_na, ea_q1_lb_no_rtg_dsa, ea_q1_lb_rtg_dsa, ea_q1_lb_rtg_na]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
# Using a learning rate of 1e-3
ea_q1_lb_no_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_no_rtg_dsa_CartPole-v0_25-09-2021_16-19-21/events.out.tfevents.1632611961.triton2')
ea_q1_lb_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_rtg_dsa_CartPole-v0_25-09-2021_16-19-50/events.out.tfevents.1632611990.triton2')
ea_q1_lb_rtg_na = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_rtg_na_CartPole-v0_25-09-2021_16-20-22/events.out.tfevents.1632612022.triton2')
ea_q1_sb_no_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_no_rtg_dsa_CartPole-v0_25-09-2021_16-18-21/events.out.tfevents.1632611901.triton2')
ea_q1_sb_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_rtg_dsa_CartPole-v0_25-09-2021_16-18-49/events.out.tfevents.1632611929.triton2')
ea_q1_sb_rtg_na = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_rtg_na_CartPole-v0_25-09-2021_16-19-07/events.out.tfevents.1632611947.triton2')
ea_list = [ea_q1_sb_no_rtg_dsa, ea_q1_sb_rtg_dsa, ea_q1_sb_rtg_na, ea_q1_lb_no_rtg_dsa, ea_q1_lb_rtg_dsa, ea_q1_lb_rtg_na]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
# Using a learning rate of 1e-2
ea_q1_lb_no_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_no_rtg_dsa_CartPole-v0_25-09-2021_16-31-03/events.out.tfevents.1632612663.triton2')
ea_q1_lb_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_rtg_dsa_CartPole-v0_25-09-2021_16-31-40/events.out.tfevents.1632612700.triton2')
ea_q1_lb_rtg_na = event_accumulator.EventAccumulator('data/q2_pg_q1_lb_rtg_na_CartPole-v0_25-09-2021_16-32-13/events.out.tfevents.1632612733.triton2')
ea_q1_sb_no_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_no_rtg_dsa_CartPole-v0_25-09-2021_16-30-14/events.out.tfevents.1632612614.triton2')
ea_q1_sb_rtg_dsa = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_rtg_dsa_CartPole-v0_25-09-2021_16-30-41/events.out.tfevents.1632612641.triton2')
ea_q1_sb_rtg_na = event_accumulator.EventAccumulator('data/q2_pg_q1_sb_rtg_na_CartPole-v0_25-09-2021_16-30-51/events.out.tfevents.1632612651.triton2')
ea_list = [ea_q1_sb_no_rtg_dsa, ea_q1_sb_rtg_dsa, ea_q1_sb_rtg_na, ea_q1_lb_no_rtg_dsa, ea_q1_lb_rtg_dsa, ea_q1_lb_rtg_na]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
def get_summary_df(ea):
    result = pd.DataFrame(ea.Scalars('Eval_AverageReturn'))
    result = result.rename(columns={"value": "Eval_AverageReturn"})
    result['Eval_StdReturn'] = [e.value for e in ea.Scalars('Eval_StdReturn')]
    result['Train_AverageReturn'] = [e.value for e in ea.Scalars('Train_AverageReturn')]
    return result

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#        wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0   1.632613e+09     0           44.000000       26.107470
# 1   1.632613e+09     1           35.000000       13.874437
# 2   1.632613e+09     2           62.857143       22.837490
# 3   1.632613e+09     3           55.000000       17.528547
# 4   1.632613e+09     4          108.599998       61.265324
# ..           ...   ...                 ...             ...
# 95  1.632613e+09    95           53.000000        5.744563
# 96  1.632613e+09    96           62.857143        9.062144
# 97  1.632613e+09    97           63.000000       10.378550
# 98  1.632613e+09    98           66.666664        9.826269
# 99  1.632613e+09    99           69.000000        9.504385
#
#     Train_AverageReturn
# 0             27.648649
# 1             42.599998
# 2             37.555557
# 3             53.000000
# 4             68.000000
# ..                  ...
# 95            47.761906
# 96            56.277779
# 97            58.944443
# ...

# %%
fig = plt.figure()
label_list = ['sb_no_rtg_dsa', 'sb_rtg_dsa', 'sb_rtg_na', 'lb_no_rtg_dsa', 'lb_rtg_dsa', 'lb_rtg_na']
for i in range(3):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=np.maximum(result.Eval_AverageReturn-result.Eval_StdReturn, 0), 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='lower right')
plt.title('PG Learning Curves Small Batch')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()
# Out:
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
fig = plt.figure()
label_list = ['sb_no_rtg_dsa', 'sb_rtg_dsa', 'sb_rtg_na', 'lb_no_rtg_dsa', 'lb_rtg_dsa', 'lb_rtg_na']
for i in range(3,6):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=np.maximum(result.Eval_AverageReturn-result.Eval_StdReturn, 0), 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='lower right')
plt.title('PG Learning Curves Large Batch')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()

# %% [markdown]
# # Experiment 2

# %%
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b1000_r5e-3_InvertedPendulum-v2_25-09-2021_16-53-37/events.out.tfevents.1632614017.triton2') # ok
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b512_r1e-2_InvertedPendulum-v2_25-09-2021_16-55-30/events.out.tfevents.1632614130.triton2') # ok
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b256_r1e-2_InvertedPendulum-v2_25-09-2021_16-56-38/events.out.tfevents.1632614198.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r1e-2_InvertedPendulum-v2_25-09-2021_17-02-25/events.out.tfevents.1632614545.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r5e-3_InvertedPendulum-v2_25-09-2021_17-03-02/events.out.tfevents.1632614582.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r1e-2_InvertedPendulum-v2_25-09-2021_17-08-14/events.out.tfevents.1632614894.triton2')# 3, 256
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r5e-3_InvertedPendulum-v2_25-09-2021_17-08-38/events.out.tfevents.1632614918.triton2')# 3, 256 ok
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r1e-2_InvertedPendulum-v2_25-09-2021_17-12-46/events.out.tfevents.1632615166.triton2')# seed 2 ok
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r5e-3_InvertedPendulum-v2_25-09-2021_17-12-58/events.out.tfevents.1632615178.triton2')# seed 2
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b64_r1e-2_InvertedPendulum-v2_25-09-2021_17-16-48/events.out.tfevents.1632615408.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b64_r5e-2_InvertedPendulum-v2_25-09-2021_17-17-33/events.out.tfevents.1632615453.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b64_r1e-2_InvertedPendulum-v2_25-09-2021_17-19-38/events.out.tfevents.1632615578.triton2')# seed 2
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b64_r5e-2_InvertedPendulum-v2_25-09-2021_17-19-47/events.out.tfevents.1632615587.triton2')# seed 2
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r5e-2_InvertedPendulum-v2_25-09-2021_17-21-43/events.out.tfevents.1632615703.triton2') # ok
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r2e-2_InvertedPendulum-v2_25-09-2021_17-22-10/events.out.tfevents.1632615730.triton2') # ok
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r1e-1_InvertedPendulum-v2_25-09-2021_17-24-18/events.out.tfevents.1632615858.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r2e-1_InvertedPendulum-v2_25-09-2021_17-24-39/events.out.tfevents.1632615879.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r8e-2_InvertedPendulum-v2_25-09-2021_17-26-28/events.out.tfevents.1632615988.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r9e-2_InvertedPendulum-v2_25-09-2021_17-27-01/events.out.tfevents.1632616021.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r6e-2_InvertedPendulum-v2_25-09-2021_17-28-53/events.out.tfevents.1632616133.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r7e-2_InvertedPendulum-v2_25-09-2021_17-29-08/events.out.tfevents.1632616148.triton2')
ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r5e-2_InvertedPendulum-v2_25-09-2021_17-30-40/events.out.tfevents.1632616240.triton2')
# ea = event_accumulator.EventAccumulator('data/q2_pg_q2_b128_r5e-2_InvertedPendulum-v2_25-09-2021_17-31-15/events.out.tfevents.1632616275.triton2') # seed 2

ea.Reload() 
ea.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result = get_summary_df(ea)
fig = plt.figure()

plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = 'q2_b128_r5e-2')
plt.fill_between(x=result.step, y1=np.maximum(result.Eval_AverageReturn-result.Eval_StdReturn, 0), 
                 y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='upper left')
plt.title('PG Learning Curves on InvertedPendulum')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()

# %% [markdown]
# # Experiment 3

# %%
ea = event_accumulator.EventAccumulator('data/q2_pg_q3_b40000_r0.005_LunarLanderContinuous-v2_25-09-2021_19-18-37/events.out.tfevents.1632622717.triton2')
ea.Reload() 
ea.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result = get_summary_df(ea)
fig = plt.figure(figsize=(10,6))

plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = 'q3_b40000_r0.005')
plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                 y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='upper left')
plt.title('PG Learning Curves on LunarLanderContinuous-v2')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()

# %% [markdown]
# # Experiment 4

# %%
ea_q4_search_b10000_lr001 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b10000_lr0.01_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-22-51/events.out.tfevents.1632622971.triton2')
ea_q4_search_b10000_lr002 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b10000_lr0.02_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-24-09/events.out.tfevents.1632623049.triton2')
ea_q4_search_b10000_lr0005 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b10000_lr0.005_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-22-39/events.out.tfevents.1632622959.triton2')
ea_q4_search_b30000_lr001 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b30000_lr0.01_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-24-30/events.out.tfevents.1632623070.triton2')
ea_q4_search_b30000_lr002 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b30000_lr0.02_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-24-38/events.out.tfevents.1632623078.triton2')
ea_q4_search_b30000_lr0005 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b30000_lr0.005_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-24-22/events.out.tfevents.1632623062.triton2')
ea_q4_search_b50000_lr001 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b50000_lr0.01_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-24-56/events.out.tfevents.1632623096.triton2')
ea_q4_search_b50000_lr002 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b50000_lr0.02_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-25-04/events.out.tfevents.1632623104.triton2')
ea_q4_search_b50000_lr0005 = event_accumulator.EventAccumulator('data/q2_pg_q4_search_b50000_lr0.005_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_19-24-47/events.out.tfevents.1632623087.triton2')

ea_list = [ea_q4_search_b10000_lr001, ea_q4_search_b10000_lr002, ea_q4_search_b10000_lr0005,
           ea_q4_search_b30000_lr001, ea_q4_search_b30000_lr002, ea_q4_search_b30000_lr0005,
           ea_q4_search_b50000_lr001, ea_q4_search_b50000_lr002, ea_q4_search_b50000_lr0005]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#        wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0   1.632623e+09     0          -95.356087       36.589703
# 1   1.632623e+09     1          -74.513252       47.532482
# 2   1.632623e+09     2          -83.095123       50.959381
# 3   1.632623e+09     3          -65.486145       35.039772
# 4   1.632623e+09     4          -78.673767       50.984200
# ..           ...   ...                 ...             ...
# 95  1.632624e+09    95           64.974586        7.489758
# 96  1.632624e+09    96           44.980610       21.601440
# 97  1.632624e+09    97           36.730038        8.191689
# 98  1.632624e+09    98           62.972900       14.831039
# 99  1.632624e+09    99           72.743629        5.057199
#
#     Train_AverageReturn
# 0            -89.742012
# 1            -77.020508
# 2            -79.937897
# 3            -88.069984
# 4            -76.278168
# ..                  ...
# 95            56.609764
# 96            60.516247
# 97            66.268143
# ...

# %%
fig = plt.figure(figsize=(12,8))
label_list = ['q4_b10000_lr0.01', 'q4_b10000_lr0.02', 'q4_b10000_lr0.005', 
              'q4_b30000_lr0.01', 'q4_b30000_lr0.02', 'q4_b30000_lr0.005', 
              'q4_b50000_lr0.01', 'q4_b50000_lr0.02', 'q4_b50000_lr0.005']
for i in range(9):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='lower right')
plt.title('PG Learning Curves HalfCheetah-v2')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()
# Out:
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
final_reward = []
for result in result_list:
    final_reward.append(result.Eval_AverageReturn[99])
final_reward
# Out:
# [72.7436294555664,
#  91.14810943603516,
#  -21.947235107421875,
#  130.0980682373047,
#  127.5288314819336,
#  16.40892219543457,
#  148.31422424316406,
#  164.3522186279297,
#  43.88456726074219]

# %%
pd.DataFrame({'name':label_list, 'final_reward': final_reward}).sort_values('final_reward')
# Out:
#              name  final_reward
# 2  b10000_lr0.005    -21.947235
# 5  b30000_lr0.005     16.408922
# 8  b50000_lr0.005     43.884567
# 0   b10000_lr0.01     72.743629
# 1   b10000_lr0.02     91.148109
# 4   b30000_lr0.02    127.528831
# 3   b30000_lr0.01    130.098068
# 6   b50000_lr0.01    148.314224
# 7   b50000_lr0.02    164.352219

# %%
ea_q4_b50000_r002 = event_accumulator.EventAccumulator('data/q2_pg_q4_b50000_r0.02_HalfCheetah-v2_25-09-2021_21-12-30/events.out.tfevents.1632629550.triton2')
ea_q4_b50000_r002_nnbaseline = event_accumulator.EventAccumulator('data/q2_pg_q4_b50000_r0.02_nnbaseline_HalfCheetah-v2_25-09-2021_21-12-49/events.out.tfevents.1632629569.triton2')
ea_qq4_b50000_r002_rtg = event_accumulator.EventAccumulator('data/q2_pg_q4_b50000_r0.02_rtg_HalfCheetah-v2_25-09-2021_21-12-41/events.out.tfevents.1632629561.triton2')
ea_q4_b50000_r002_rtg_nnbaseline = event_accumulator.EventAccumulator('data/q2_pg_q4_b50000_r0.02_rtg_nnbaseline_HalfCheetah-v2_25-09-2021_21-12-57/events.out.tfevents.1632629577.triton2')

ea_list = [ea_q4_b50000_r002, ea_q4_b50000_r002_nnbaseline, ea_qq4_b50000_r002_rtg, ea_q4_b50000_r002_rtg_nnbaseline]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#        wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0   1.632630e+09     0         -108.756599        6.347118
# 1   1.632630e+09     1          -81.158363        8.386088
# 2   1.632630e+09     2         -131.281342       36.936512
# 3   1.632630e+09     3         -113.680176       14.935624
# 4   1.632630e+09     4          -99.015144       12.344732
# ..           ...   ...                 ...             ...
# 95  1.632633e+09    95           23.859453       14.320768
# 96  1.632633e+09    96           43.131405       24.941093
# 97  1.632633e+09    97           34.707043       15.649547
# 98  1.632633e+09    98           20.425667       29.491520
# 99  1.632633e+09    99          -35.150898       45.809986
#
#     Train_AverageReturn
# 0            -91.181145
# 1            -93.004791
# 2           -100.392746
# 3           -111.042557
# 4           -113.973183
# ..                  ...
# 95            27.638130
# 96            30.638889
# 97            29.659180
# ...

# %%
fig = plt.figure(figsize=(12,8))
label_list = ['q4_b50000_r0.02', 'q4_b50000_r0.02_nnbaseline', 'q4_b50000_r0.02_rtg', 'q4_b50000_r0.02_rtg_nnbaseline']
for i in range(4):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='upper left')
plt.title('PG Learning Curves HalfCheetah-v2')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()

# %% [markdown]
# # Experiment 5

# %%
ea_q5_b2000_r0001_lambda0 = event_accumulator.EventAccumulator('data/q2_pg_q5_b2000_r0.001_lambda0_Hopper-v2_25-09-2021_19-32-31/events.out.tfevents.1632623551.triton2')
ea_q5_b2000_r0001_lambda095 = event_accumulator.EventAccumulator('data/q2_pg_q5_b2000_r0.001_lambda0.95_Hopper-v2_25-09-2021_19-32-43/events.out.tfevents.1632623563.triton2')
ea_q5_b2000_r0001_lambda099 = event_accumulator.EventAccumulator('data/q2_pg_q5_b2000_r0.001_lambda0.99_Hopper-v2_25-09-2021_19-32-52/events.out.tfevents.1632623572.triton2')
ea_q5_b2000_r0001_lambda1 = event_accumulator.EventAccumulator('data/q2_pg_q5_b2000_r0.001_lambda1_Hopper-v2_25-09-2021_19-33-00/events.out.tfevents.1632623580.triton2')
ea_list = [ea_q5_b2000_r0001_lambda0, ea_q5_b2000_r0001_lambda095, ea_q5_b2000_r0001_lambda099, ea_q5_b2000_r0001_lambda1]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#         wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0    1.632624e+09     0            9.893888        6.417144
# 1    1.632624e+09     1            9.647307        5.211866
# 2    1.632624e+09     2           10.090631        5.277081
# 3    1.632624e+09     3           10.549361        5.719665
# 4    1.632624e+09     4           15.593706       25.630243
# ..            ...   ...                 ...             ...
# 295  1.632625e+09   295           86.743904        6.758524
# 296  1.632625e+09   296           76.624069        7.945755
# 297  1.632625e+09   297           77.282898        8.660738
# 298  1.632625e+09   298           74.741463        7.742819
# 299  1.632625e+09   299           84.503227        7.461076
#
#      Train_AverageReturn
# 0              10.082236
# 1              11.112199
# 2              10.613735
# 3              11.323121
# 4              10.250557
# ..                   ...
# 295            78.873657
# 296            79.358559
# ...

# %%
fig = plt.figure(figsize=(10,6))
label_list = ['q5_b2000_r0001_lambda0', 'q5_b2000_r0001_lambda0.95', 'q5_b2000_r0001_lambda0.99', 'q5_b2000_r0001_lambda1']
for i in range(4):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='upper left')
plt.title('PG Learning Curves HopperV2')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()

# %% [markdown]
# # Experiment 6

# %% [markdown]
# ### LunarLander

# %%
ea_q5_b20000_r0005_nstep1 = event_accumulator.EventAccumulator('data/q2_pg_q6_b20000_r0.005_nstep1_LunarLanderContinuous-v2_25-09-2021_22-19-32/events.out.tfevents.1632633572.triton2')
ea_q5_b20000_r0005_nstep2 = event_accumulator.EventAccumulator('data/q2_pg_q6_b20000_r0.005_nstep2_LunarLanderContinuous-v2_25-09-2021_22-21-12/events.out.tfevents.1632633672.triton2')
ea_q5_b20000_r0005_nstep3 = event_accumulator.EventAccumulator('data/q2_pg_q6_b20000_r0.005_nstep3_LunarLanderContinuous-v2_25-09-2021_22-21-25/events.out.tfevents.1632633685.triton2')
ea_q5_b20000_r0005_nstep5 = event_accumulator.EventAccumulator('data/q2_pg_q6_b20000_r0.005_nstep5_LunarLanderContinuous-v2_25-09-2021_22-21-40/events.out.tfevents.1632633700.triton2')
ea_q5_b20000_r0005_nstep10 = event_accumulator.EventAccumulator('data/q2_pg_q6_b20000_r0.005_nstep10_LunarLanderContinuous-v2_25-09-2021_22-21-55/events.out.tfevents.1632633715.triton2')
ea_list = [ea_q5_b2000_r0005_nstep1, ea_q5_b2000_r0005_nstep2, ea_q5_b2000_r0005_nstep3, ea_q5_b2000_r0005_nstep5, ea_q5_b2000_r0005_nstep10]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#        wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0   1.632634e+09     0         -221.765076      140.544540
# 1   1.632634e+09     1         -135.959854       66.973015
# 2   1.632634e+09     2         -125.234581       27.489426
# 3   1.632634e+09     3         -121.262917       57.731930
# 4   1.632634e+09     4         -121.730881       42.878773
# ..           ...   ...                 ...             ...
# 95  1.632637e+09    95          110.155167        0.000000
# 96  1.632637e+09    96          138.809723        0.000000
# 97  1.632637e+09    97          123.591995        0.000000
# 98  1.632637e+09    98          148.183975        0.000000
# 99  1.632637e+09    99          137.135757        0.000000
#
#     Train_AverageReturn
# 0           -330.988586
# 1           -183.128265
# 2           -138.867950
# 3           -129.182983
# 4           -120.792625
# ..                  ...
# 95           108.539467
# 96           139.643768
# 97           136.889877
# ...

# %%
fig = plt.figure(figsize=(10,6))
label_list = ['q6_b20000_r0005_nstep1', 'q6_b20000_r0005_nstep2', 'q6_b20000_r0005_nstep3', 'q6_b20000_r0005_nstep5', 'q6_b20000_r0005_nstep10']
for i in range(5):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='lower left')
plt.title('PG Learning Curves LunarLanderContinuous-v2')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()
# Out:
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/lawrence/homework_fall2021/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# ### HalfCheetah

# %%
ea_q6_b30000_r001_nstep1 = event_accumulator.EventAccumulator('data/q2_pg_q4_b30000_r0.01_rtg_nnbaseline_nstep1_HalfCheetah-v2_25-09-2021_23-22-25/events.out.tfevents.1632637345.triton2')
ea_q6_b30000_r001_nstep2 = event_accumulator.EventAccumulator('data/q2_pg_q4_b30000_r0.01_rtg_nnbaseline_nstep2_HalfCheetah-v2_25-09-2021_23-22-38/events.out.tfevents.1632637358.triton2')
ea_q6_b30000_r001_nstep3 = event_accumulator.EventAccumulator('data/q2_pg_q4_b30000_r0.01_rtg_nnbaseline_nstep3_HalfCheetah-v2_25-09-2021_23-22-50/events.out.tfevents.1632637370.triton2')
ea_q6_b30000_r001_nstep5 = event_accumulator.EventAccumulator('data/q2_pg_q4_b30000_r0.01_rtg_nnbaseline_nstep5_HalfCheetah-v2_25-09-2021_23-23-03/events.out.tfevents.1632637383.triton2')
ea_q6_b30000_r001_nstep10 = event_accumulator.EventAccumulator('data/q2_pg_q4_b30000_r0.01_rtg_nnbaseline_nstep10_HalfCheetah-v2_25-09-2021_23-23-17/events.out.tfevents.1632637397.triton2')
ea_list = [ea_q6_b30000_r001_nstep1, ea_q6_b30000_r001_nstep2, ea_q6_b30000_r001_nstep3, ea_q6_b30000_r001_nstep5, ea_q6_b30000_r001_nstep10]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#        wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0   1.632637e+09     0          -95.460205       34.863937
# 1   1.632637e+09     1          -80.498001       39.402462
# 2   1.632637e+09     2          -61.957348       23.766441
# 3   1.632637e+09     3          -68.893532       16.528505
# 4   1.632637e+09     4          -75.097527       34.952789
# ..           ...   ...                 ...             ...
# 95  1.632640e+09    95          112.795715        5.507381
# 96  1.632640e+09    96          129.415207        5.843694
# 97  1.632640e+09    97          122.941780       14.443572
# 98  1.632640e+09    98          110.841240        7.572609
# 99  1.632640e+09    99          130.098068       37.858776
#
#     Train_AverageReturn
# 0            -90.006058
# 1            -85.142685
# 2            -76.971497
# 3            -75.769012
# 4            -77.240211
# ..                  ...
# 95           107.913162
# 96           116.214394
# 97           122.160744
# ...

# %%
fig = plt.figure(figsize=(10,6))
label_list = ['q6_b30000_r001_nstep1', 'q6_b30000_r001_nstep2', 'q6_b30000_r001_nstep3', 'q6_b30000_r001_nstep5', 'q6_b30000_r001_nstep10']
for i in range(5):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='lower left')
plt.title('PG Learning Curves HalfCheetah-v2')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()

# %% [markdown]
# ### HalfCheetah

# %%
ea_q6_lb_rtg_na_nstep1 = event_accumulator.EventAccumulator('data/q2_pg_q6_lb_rtg_na_CartPole-v0_26-09-2021_00-07-00/events.out.tfevents.1632640020.triton2')
ea_q6_lb_rtg_na_nstep2 = event_accumulator.EventAccumulator('data/q2_pg_q6_lb_rtg_na_nstep2_CartPole-v0_26-09-2021_00-14-57/events.out.tfevents.1632640497.triton2')
ea_q6_lb_rtg_na_nstep3 = event_accumulator.EventAccumulator('data/q2_pg_q6_lb_rtg_na_nstep3_CartPole-v0_26-09-2021_00-15-13/events.out.tfevents.1632640513.triton2')
ea_q6_lb_rtg_na_nstep5 = event_accumulator.EventAccumulator('data/q2_pg_q6_lb_rtg_na_nstep5_CartPole-v0_26-09-2021_00-15-28/events.out.tfevents.1632640528.triton2')
ea_list = [ea_q6_lb_rtg_na_nstep1, ea_q6_lb_rtg_na_nstep2, ea_q6_lb_rtg_na_nstep3, ea_q6_lb_rtg_na_nstep5]
ea_list = [ea.Reload() for ea in ea_list]
ea_q1_sb_no_rtg_dsa.Tags()
# Out:
# {'images': [],
#  'audio': [],
#  'histograms': [],
#  'scalars': ['Eval_AverageReturn',
#   'Eval_StdReturn',
#   'Eval_MaxReturn',
#   'Eval_MinReturn',
#   'Eval_AverageEpLen',
#   'Train_AverageReturn',
#   'Train_StdReturn',
#   'Train_MaxReturn',
#   'Train_MinReturn',
#   'Train_AverageEpLen',
#   'Train_EnvstepsSoFar',
#   'TimeSinceStart',
#   'Training_Loss',
#   'Initial_DataCollection_AverageReturn'],
#  'distributions': [],
#  'tensors': [],
#  'graph': False,
#  'meta_graph': False,
#  'run_metadata': []}

# %%
result_list = list(map(get_summary_df, ea_list))
for result in result_list:
    display(result)
# Out:
#        wall_time  step  Eval_AverageReturn  Eval_StdReturn  \
# 0   1.632640e+09     0           31.500000       17.622023
# 1   1.632640e+09     1           46.000000       20.789955
# 2   1.632640e+09     2           72.500000       60.497246
# 3   1.632640e+09     3           82.599998       36.456001
# 4   1.632640e+09     4           90.000000       46.445667
# ..           ...   ...                 ...             ...
# 95  1.632640e+09    95          200.000000        0.000000
# 96  1.632640e+09    96          200.000000        0.000000
# 97  1.632640e+09    97          200.000000        0.000000
# 98  1.632640e+09    98          200.000000        0.000000
# 99  1.632640e+09    99          200.000000        0.000000
#
#     Train_AverageReturn
# 0             25.658163
# 1             35.232395
# 2             40.821136
# 3             51.193878
# 4             69.027397
# ..                  ...
# 95           199.384613
# 96           191.925919
# 97           197.461533
# ...

# %%
fig = plt.figure(figsize=(10,6))
label_list = ['q6_lb_rtg_na_nstep1', 'q6_lb_rtg_na_nstep2', 'q6_lb_rtg_na_nstep3', 'q6_lb_rtg_na_nstep5']
for i in range(4):
    result = result_list[i]
    plt.plot(result.step, result.Eval_AverageReturn, linestyle='-', label = label_list[i])
    plt.fill_between(x=result.step, y1=result.Eval_AverageReturn-result.Eval_StdReturn, 
                     y2=result.Eval_AverageReturn+result.Eval_StdReturn, alpha=0.2)
plt.legend(loc='lower right')
plt.title('PG Learning Curves CartPole-v0')
plt.xlabel('Number of Iterations')
plt.ylabel('Eval Average Return Each Path')
plt.show()
